# %% [markdown]
# # Running a Federated Cycle with Synergos
#
# In a federated learning system, there are many contributory participants, known as Worker nodes, which receive a global model to train on, with their own local dataset. The dataset does not leave the individual Worker nodes at any point, and remains private to the node.
#
# The job to synchronize, orchestrate and initiate an federated learning cycle, falls on a Trusted Third Party (TTP). The TTP pushes out the global model architecture and parameters for the individual nodes to train on, calling upon the required data, based on tags, e.g "training", which points to relevant data on the individual nodes. At no point does the TTP receive, copy or access the Worker nodes' local datasets.
#
# ![Simulated Synergos Cluster Grid](../../docs/images/syncluster_setup.png "A simple Synergos Cluster setup")
#
# This tutorial aims to give you an understanding of how to use the synergos package to run a full federated learning cycle on a `Synergos Cluster` grid.
#
# In a `Synergos Cluster` Grid, with the inclusion of a new director and queue component, you will be able to parallelize your jobs, where the number of concurrent jobs possible is equal to the number of sub-grids. This is done alongside all quality-of-life components supported in a `Synergos Plus` grid.
#
# In this tutorial, you will go through the steps required by each participant (TTP and Worker), by simulating each of them locally with docker containers. Specifically, we will simulate a Director and 2 sub-grids, each of which has a TTP and 2 Workers, allowing us to perform 2 concurrent federated operations at any time.
#
# At the end of this, we will have:
# - Connected the participants
# - Trained the model
# - Evaluate the model
#
# ## About the Dataset and Task
#
# The dataset used in this notebook is on heart disease tabular data, comprising 14 predictor features, and 1 target feature for a binary class. The dataset is available in the same directory as this notebook. Within the dataset directory, `data1` is for Worker 1 and `data2` is for Worker 2. The task to be carried out will be a binary classifcation.
#
# The dataset we have provided is a processed subset of the [original Heart Disease dataset](https://archive.ics.uci.edu/ml/datasets/heart+disease).
#
# **Reference:**
# - *Dua, D. and Graff, C. (2019). UCI Machine Learning Repository [http://archive.ics.uci.edu/ml]. Irvine, CA: University of California, School of Information and Computer Science.*

# %% [markdown]
# ## Initiating the docker containers
#
# Before we begin, we have to start the docker containers.

# %% [markdown]
# ### A. Initialization via `Synergos Simulator`
#
# In `Synergos Simulator`, a sandboxed environment has been created for you!
#
# By running:
#
#     `docker-compose -f docker-compose-syncluster.yml up --build`
#
# the following components will be started:
# - Director
# - Sub-Grid 1
#   - TTP_1 (Cluster)
#   - Worker_1_n1
#   - Worker_2_n1
# - Sub-Grid 2
#   - TTP_2 (Cluster)
#   - Worker_1_n2
#   - Worker_2_n2
# - Synergos UI
# - Synergos Logger
# - Synergos MLOps
# - Synergos MQ
#
# Refer to [this](https://github.com/aimakerspace/synergos_simulator) for all the pre-allocated host & port mappings.

# %% [markdown]
# ### B. Manual Initialization
#
# Firstly, pull the required docker images with the following commands:
#
# 1. Synergos Director:
#
#     `docker pull gcr.io/synergos-aisg/synergos_director:v0.1.0`
#
# 2. Synergos TTP (Cluster):
#
#     `docker pull gcr.io/synergos-aisg/synergos_ttp_cluster:v0.1.0`
#
# 3. Synergos Worker:
#
#     `docker pull gcr.io/synergos-aisg/synergos_worker:v0.1.0`
#
# 4. Synergos MLOps:
#
#     `docker pull gcr.io/synergos-aisg/synergos_mlops:v0.1.0`
#
# 5. Synergos MQ:
#
#     `docker pull gcr.io/synergos-aisg/synergos_mq:v0.1.0`
#
# Next, in <u>separate</u> CLI terminals, run the following command(s):
#
# **Note: For Windows users, it is advisable to use powershell or command prompt based interfaces**
#
# #### Director
#
# ```
# docker run --rm
#     -p 5000:5000
#     -v <directory heart_disease/orchestrator_data>:/orchestrator/data
#     -v <directory heart_disease/orchestrator_outputs>:/orchestrator/outputs
#     -v <directory heart_disease/mlflow>:/mlflow
#     --name director
#     gcr.io/synergos-aisg/synergos_director:v0.1.0
#         --id ttp
#         --logging_variant graylog <IP Synergos Logger> <TTP port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# #### Sub-Grid 1
#
# - **TTP_1**
# ```
# docker run --rm
#     -p 6000:5000
#     -p 9020:8020
#     -v <directory heart_disease/orchestrator_data>:/orchestrator/data
#     -v <directory heart_disease/orchestrator_outputs>:/orchestrator/outputs
#     --name ttp_1
#     gcr.io/synergos-aisg/synergos_ttp_cluster:v0.1.0
#         --id ttp
#         --logging_variant graylog <IP Synergos Logger> <TTP port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# - **WORKER_1 Node 1**
# ```
# docker run --rm
#     -p 5001:5000
#     -p 8021:8020
#     -v <directory heart_disease/data1>:/worker/data
#     -v <directory heart_disease/outputs_1>:/worker/outputs
#     --name worker_1_n1
#     gcr.io/synergos-aisg/synergos_worker:v0.1.0
#         --id worker_1_n1
#         --logging_variant graylog <IP Synergos Logger> <Worker port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# - **WORKER_2 Node 1**
# ```
# docker run --rm
#     -p 5002:5000
#     -p 8022:8020
#     -v <directory heart_disease/data2>:/worker/data
#     -v <directory heart_disease/outputs_2>:/worker/outputs
#     --name worker_2_n1
#     gcr.io/synergos-aisg/synergos_worker:v0.1.0
#         --id worker_2_n1
#         --logging_variant graylog <IP Synergos Logger> <Worker port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# #### Sub-Grid 2
#
# - **TTP_2**
# ```
# docker run --rm
#     -p 7000:5000
#     -p 10020:8020
#     -v <directory heart_disease/orchestrator_data>:/orchestrator/data
#     -v <directory heart_disease/orchestrator_outputs>:/orchestrator/outputs
#     --name ttp_2
#     gcr.io/synergos-aisg/synergos_ttp_cluster:v0.1.0
#         --id ttp
#         --logging_variant graylog <IP Synergos Logger> <TTP port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# - **WORKER_1 Node 2**
# ```
# docker run --rm
#     -p 5003:5000
#     -p 8023:8020
#     -v <directory heart_disease/data1>:/worker/data
#     -v <directory heart_disease/outputs_1>:/worker/outputs
#     --name worker_1_n2
#     gcr.io/synergos-aisg/synergos_worker:v0.1.0
#         --id worker_1_n2
#         --logging_variant graylog <IP Synergos Logger> <Worker port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# - **WORKER_2 Node 2**
# ```
# docker run --rm
#     -p 5004:5000
#     -p 8024:8020
#     -v <directory heart_disease/data2>:/worker/data
#     -v <directory heart_disease/outputs_2>:/worker/outputs
#     --name worker_2_n2
#     gcr.io/synergos-aisg/synergos_worker:v0.1.0
#         --id worker_2_n2
#         --logging_variant graylog <IP Synergos Logger> <Worker port>
#         --queue rabbitmq <IP Synergos Logger> <AMQP port>
# ```
#
# #### Synergos MLOps
#
# ```
# docker run --rm
#     -p 5500:5500
#     -v /path/to/mlflow_test/:/mlflow    # <-- IMPT! Same as orchestrator's
#     --name synmlops
#     gcr.io/synergos-aisg/synergos_mlops:v0.1.0
# ```
#
# #### Synergos MQ
#
# ```
# docker run --rm
#     -p 15672:15672      # UI port
#     -p 5672:5672        # AMQP port
#     --name synergos_mq
#     gcr.io/synergos-aisg/synergos_mq:v0.1.0
# ```
#
# #### Synergos UI
#
# - Refer to these [instructions](https://github.com/aimakerspace/synergos_ui) to deploy `Synergos UI`.
#
# #### Synergos Logger
#
# - Refer to these [instructions](https://github.com/aimakerspace/synergos_logger) to deploy `Synergos Logger`.

# %% [markdown]
# Once ready, for each terminal, you should see a REST server running on http://0.0.0.0:5000 of the container.
#
# You are now ready for the next step.

# %% [markdown]
# ## Configurations

# %% [markdown]
# ### A. Configuring `Synergos Simulator`
#
# All hosts & ports have already been pre-allocated!
#
# Refer to [this](https://github.com/aimakerspace/synergos_simulator) for all the pre-allocated host & port mappings.

# %% [markdown]
# ### B. Configuring your manual setup
#
# In a new terminal, run `docker inspect bridge` and find the IPv4Address for each container. Ideally, the containers should have the following addresses:
# - director address: `172.17.0.2`
# - Sub-Grid 1
#   - ttp_1 address: `172.17.0.3`
#   - worker_1_n1 address: `172.17.0.4`
#   - worker_2_n1 address: `172.17.0.5`
# - Sub-Grid 2
#   - ttp_2 address: `172.17.0.6`
#   - worker_1_n2 address: `172.17.0.7`
#   - worker_2_n2 address: `172.17.0.8`
# - UI address: `172.17.0.9`
# - Logger address: `172.17.0.14`
# - MLOps address: `172.17.0.15`
# - MQ address: `172.17.0.16`
#
# If not, just note the relevant IP addresses for each docker container.
#
# Run the following cells below.
#
# **Note: For Windows users, `host` should be Docker Desktop VM's IP. Follow [this](https://stackoverflow.com/questions/58073936/how-to-get-ip-address-of-docker-desktop-vm) on instructions to find IP**

# %%
import time
from synergos import Driver

host = "172.20.0.2"
port = 5000

# Initiate Driver
driver = Driver(host=host, port=port)

# %% [markdown]
# ## Phase 1: Registration
#
# Submitting Orchestrator & Participant metadata

# %% [markdown]
# #### 1A. Orchestrator creates a collaboration

# %%
collab_task = driver.collaborations

collab_task.configure_logger(
    host="172.20.0.14", 
    port=9000, 
    sysmetrics_port=9100, 
    director_port=9200, 
    ttp_port=9300, 
    worker_port=9400, 
    ui_port=9000, 
    secure=False
)

collab_task.configure_mlops( 
    host="172.20.0.15", 
    port=5500, 
    ui_port=5500, 
    secure=False
)

collab_task.configure_mq( 
    host="172.20.0.16", 
    port=5672, 
    ui_port=15672, 
    secure=False
)

collab_task.create('heart_disease_syncluster_collaboration')
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Collaboration',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration'},
#   'relations': {'Project': [],
#    'Experiment': [],
#    'Run': [],
#    'Registration': [],
#    'Tag': [],
#    'Model': [],
#    'Validation': [],
#    'Prediction': []},
#   'logs': {'host': '172.20.0.14',
#    'ports': {'sysmetrics': 9100,
#     'director': 9200,
#     'ttp': 9300,
#     'worker': 9400,
#     'main': 9000,
#     'ui': 9000},
#    'secure': False},
#   'mlops': {'host': '172.20.0.15',
#    'ports': {'main': 5500, 'ui': 5500},
#    'secure': False},
#   'mq': {'host': '172.20.0.16',
#    'ports': {'main': 5672, 'ui': 15672},
#    'secure': False}},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'collaborations.post',
#  'params': {}}

# %% [markdown]
# #### 1B. Orchestrator creates a project

# %%
driver.projects.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    action="classify",
    incentives={
        'tier_1': [],
        'tier_2': [],
    }
)
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Project',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project'},
#   'relations': {'Experiment': [],
#    'Run': [],
#    'Registration': [],
#    'Tag': [],
#    'Model': [],
#    'Validation': [],
#    'Prediction': []},
#   'action': 'classify',
#   'incentives': {'tier_2': [], 'tier_1': []}},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'projects.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration'}}

# %% [markdown]
# #### 1C. Orchestrator creates an experiment

# %%
driver.experiments.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    model=[
        {
            "activation": "sigmoid",
            "is_input": True,
            "l_type": "Linear",
            "structure": {
                "bias": True,
                "in_features": 13,
                "out_features": 1 
            }
        }
    ]
)
# Out:
# {'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'experiments.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project'},
#  'data': {'created_at': '2021-09-16 01:01:57 N',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'expt_id': 'heart_disease_syncluster_experiment',
#    'project_id': 'heart_disease_syncluster_project'},
#   'model': [{'activation': 'sigmoid',
#     'is_input': True,
#     'l_type': 'Linear',
#     'structure': {'bias': True, 'in_features': 13, 'out_features': 1}}],
#   'relations': {'Run': [], 'Model': [], 'Validation': [], 'Prediction': []},
#   'doc_id': 1,
#   'kind': 'Experiment'}}

# %% [markdown]
# #### 1D. Orchestrator creates a run

# %%
driver.runs.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
    rounds=2, 
    epochs=1,
    base_lr=0.0005,
    max_lr=0.005,
    criterion="NLLLoss"
)
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Run',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project',
#    'expt_id': 'heart_disease_syncluster_experiment',
#    'run_id': 'heart_disease_syncluster_run'},
#   'relations': {'Model': [], 'Validation': [], 'Prediction': []},
#   'rounds': 2,
#   'epochs': 1,
#   'lr': 0.001,
#   'lr_decay': 0.1,
#   'weight_decay': 0.0,
#   'seed': 42,
#   'precision_fractional': 5,
#   'mu': 0.1,
#   'l1_lambda': 0.0,
#   'l2_lambda': 0.0,
#   'base_lr': 0.0005,
#   'max_lr': 0.005,
#   'patience': 10,
#   'delta': 0.0},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'runs.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment'}}

# %% [markdown]
# #### 1E. Participants registers their servers' configurations and roles

# %%
participant_resp_1 = driver.participants.create(
    participant_id="worker_1",
)

display(participant_resp_1)

participant_resp_2 = driver.participants.create(
    participant_id="worker_2",
)

display(participant_resp_2)
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Participant',
#   'key': {'participant_id': 'worker_1'},
#   'relations': {'Registration': [], 'Tag': []},
#   'id': 'worker_1'},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'participants.post',
#  'params': {}}
# {'data': {'doc_id': '2',
#   'kind': 'Participant',
#   'key': {'participant_id': 'worker_2'},
#   'relations': {'Registration': [], 'Tag': []},
#   'id': 'worker_2'},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'participants.post',
#  'params': {}}

# %%
registration_task = driver.registrations

# Add and register worker_1 node
registration_task.add_node(
    host='172.20.0.4',
    port=8020,
    f_port=5000,
    log_msgs=True,
    verbose=True
)

registration_task.add_node(
    host='172.20.0.7',
    port=8020,
    f_port=5000,
    log_msgs=True,
    verbose=True
)

registration_task.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    participant_id="worker_1",
    role="host"
)
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Registration',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project',
#    'participant_id': 'worker_1'},
#   'relations': {'Tag': []},
#   'collaboration': {'catalogue': {},
#    'logs': {'host': '172.20.0.14',
#     'ports': {'sysmetrics': 9100,
#      'director': 9200,
#      'ttp': 9300,
#      'worker': 9400,
#      'main': 9000,
#      'ui': 9000},
#     'secure': False},
#    'meter': {},
#    'mlops': {'host': '172.20.0.15',
#     'ports': {'main': 5500, 'ui': 5500},
#     'secure': False},
#    'mq': {'host': '172.20.0.16',
#     'ports': {'main': 5672, 'ui': 15672},
#     'secure': False}},
#   'project': {'action': 'classify',
#    'incentives': {'tier_2': [], 'tier_1': []},
#    'start_at': None},
#   'participant': {'id': 'worker_1',
#    'category': [],
#    'summary': None,
#    'phone': None,
#    'email': None,
#    'socials': {}},
#   'role': 'host',
#   'n_count': 2,
#   'node_1': {'host': '172.20.0.7',
#    'port': 8020,
#    'log_msgs': True,
#    'verbose': True,
#    'f_port': 5000},
#   'node_0': {'host': '172.20.0.4',
#    'port': 8020,
#    'log_msgs': True,
#    'verbose': True,
#    'f_port': 5000}},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'registration.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'participant_id': 'worker_1'}}

# %%
registration_task = driver.registrations

# Add and register worker_2 node
registration_task.add_node(
    host='172.20.0.5',
    port=8020,
    f_port=5000,
    log_msgs=True,
    verbose=True
)

registration_task.add_node(
    host='172.20.0.8',
    port=8020,
    f_port=5000,
    log_msgs=True,
    verbose=True
)

registration_task.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    participant_id="worker_2",
    role="guest"
)
# Out:
# {'data': {'doc_id': '2',
#   'kind': 'Registration',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project',
#    'participant_id': 'worker_2'},
#   'relations': {'Tag': []},
#   'collaboration': {'catalogue': {},
#    'logs': {'host': '172.20.0.14',
#     'ports': {'sysmetrics': 9100,
#      'director': 9200,
#      'ttp': 9300,
#      'worker': 9400,
#      'main': 9000,
#      'ui': 9000},
#     'secure': False},
#    'meter': {},
#    'mlops': {'host': '172.20.0.15',
#     'ports': {'main': 5500, 'ui': 5500},
#     'secure': False},
#    'mq': {'host': '172.20.0.16',
#     'ports': {'main': 5672, 'ui': 15672},
#     'secure': False}},
#   'project': {'action': 'classify',
#    'incentives': {'tier_2': [], 'tier_1': []},
#    'start_at': None},
#   'participant': {'id': 'worker_2',
#    'category': [],
#    'summary': None,
#    'phone': None,
#    'email': None,
#    'socials': {}},
#   'role': 'guest',
#   'n_count': 2,
#   'node_1': {'host': '172.20.0.8',
#    'port': 8020,
#    'log_msgs': True,
#    'verbose': True,
#    'f_port': 5000},
#   'node_0': {'host': '172.20.0.5',
#    'port': 8020,
#    'log_msgs': True,
#    'verbose': True,
#    'f_port': 5000}},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'registration.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'participant_id': 'worker_2'}}

# %% [markdown]
# #### 1F. Participants registers their tags for a specific project

# %%
# Worker 1 declares their data tags
driver.tags.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    participant_id="worker_1",
    train=[["heart_disease", "dataset", "data1", "iid_1"]],
    evaluate=[["heart_disease", "dataset", "data1", "non_iid_1"]]
)
# Out:
# {'data': {'doc_id': '1',
#   'kind': 'Tag',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project',
#    'participant_id': 'worker_1'},
#   'train': [['heart_disease', 'dataset', 'data1', 'iid_1']],
#   'evaluate': [['heart_disease', 'dataset', 'data1', 'non_iid_1']],
#   'predict': []},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'tag.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'participant_id': 'worker_1'}}

# %%
# Worker 2 declares their data tags
driver.tags.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    participant_id="worker_2",
    train=[["heart_disease", "dataset", "data2", "iid_2"]],
    evaluate=[["heart_disease", "dataset", "data2", "non_iid_2"]]
)
# Out:
# {'data': {'doc_id': '2',
#   'kind': 'Tag',
#   'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#    'project_id': 'heart_disease_syncluster_project',
#    'participant_id': 'worker_2'},
#   'train': [['heart_disease', 'dataset', 'data2', 'iid_2']],
#   'evaluate': [['heart_disease', 'dataset', 'data2', 'non_iid_2']],
#   'predict': []},
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'tag.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'participant_id': 'worker_2'}}

# %%
stop!
# Out:
#   File "/tmp/ipykernel_16160/3319058519.py", line 1
#     stop!
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Phase 2:
# Alignment, Training & Optimisation

# %% [markdown]
# #### 2A. Perform multiple feature alignment to dynamically configure datasets and models for cross-grid compatibility

# %%
driver.alignments.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    verbose=False,
    log_msg=False
)
# Out:
# {'data': [],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 201,
#  'method': 'alignments.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project'}}

# %%
# Important! MUST wait for alignment process to first complete before proceeding on
while True:
    
    align_resp = driver.alignments.read(
        collab_id="heart_disease_syncluster_collaboration",
        project_id="heart_disease_syncluster_project"
    )
    
    align_data = align_resp.get('data')
    if align_data:
        display(align_resp)
        break
        
    time.sleep(5)
# Out:
# {'data': [{'doc_id': '1',
#    'kind': 'Alignment',
#    'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'participant_id': 'worker_1'},
#    'train': {'X': [], 'y': []},
#    'evaluate': {'X': [], 'y': []},
#    'predict': {'X': [], 'y': []}},
#   {'doc_id': '2',
#    'kind': 'Alignment',
#    'key': {'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'participant_id': 'worker_2'},
#    'train': {'X': [], 'y': []},
#    'evaluate': {'X': [], 'y': []},
#    'predict': {'X': [], 'y': []}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'alignments.get',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project'}}

# %% [markdown]
# #### 2B. Trigger training across the federated grid

# %%
model_resp = driver.models.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
    log_msg=False,
    verbose=False
)
display(model_resp)
# Out:
# {'data': [],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'models.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run'}}

# %%
# Important! MUST wait for training process to first complete before proceeding on
while True:
    
    train_resp = driver.models.read(
        collab_id="heart_disease_syncluster_collaboration",
        project_id="heart_disease_syncluster_project",
        expt_id="heart_disease_syncluster_experiment",
        run_id="heart_disease_syncluster_run"
    )
    
    train_data = train_resp.get('data')
    if train_data:
        display(train_data)
        break
        
    time.sleep(5)
# Out:
# [{'doc_id': '1',
#   'kind': 'Model',
#   'key': {'project_id': 'heart_disease_syncluster_project',
#    'expt_id': 'heart_disease_syncluster_experiment',
#    'run_id': 'heart_disease_syncluster_run'},
#   'global': {'origin': 'ttp',
#    'path': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/global_model.pt',
#    'loss_history': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/global_loss_history.json'},
#   'local_2': {'origin': 'worker_2',
#    'path': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/local_model_worker_2.pt',
#    'loss_history': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/local_loss_history_worker_2.json'},
#   'local_1': {'origin': 'worker_1',
#    'path': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/local_model_worker_1.pt',
#    'loss_history': '/orchestrator/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/local_loss_history_worker_1.json'}}]

# %% [markdown]
# #### 2C. Perform hyperparameter tuning once ideal model is found (experimental)

# %%
optim_parameters = {
    'search_space': {
        "rounds": {"_type": "choice", "_value": [1, 2]},
        "epochs": {"_type": "choice", "_value": [1, 2]},
        "batch_size": {"_type": "choice", "_value": [32, 64]},
        "lr": {"_type": "choice", "_value": [0.0001, 0.1]},
        "criterion": {"_type": "choice", "_value": ["NLLLoss"]},
        "mu": {"_type": "uniform", "_value": [0.0, 1.0]},
        "base_lr": {"_type": "choice", "_value": [0.00005]},
        "max_lr": {"_type": "choice", "_value": [0.2]}
    },
    'backend': "tune",
    'optimize_mode': "max",
    'metric': "accuracy",
    'trial_concurrency': 1,
    'max_exec_duration': "1h",
    'max_trial_num': 2,
    'max_concurrent': 1,
    'is_remote': True,
    'use_annotation': True,
    'auto_align': True,
    'dockerised': True,
    'verbose': True,
    'log_msgs': True
}
driver.optimizations.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    **optim_parameters
)
# Out:
# {'data': [{'doc_id': '2',
#    'kind': 'Optimization',
#    'key': {'participant_id': None,
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_86c76b15-3410-42e6-a908-072d85b8efc5'},
#    'evaluate': {'statistics': {}, 'res_path': None}},
#   {'doc_id': '3',
#    'kind': 'Optimization',
#    'key': {'participant_id': None,
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_8db47139-d70e-4664-8590-45b294946e32'},
#    'evaluate': {'statistics': {}, 'res_path': None}},
#   {'doc_id': '4',
#    'kind': 'Optimization',
#    'key': {'participant_id': None,
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_689a2525-bf50-414c-8738-b51f81b3e800'},
#    'evaluate': {'statistics': {}, 'res_path': None}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'optimizations.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment'}}

# %%
driver.optimizations.read(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment"
)
# Out:
# {'data': [{'doc_id': '1',
#    'kind': 'Optimization',
#    'key': {'participant_id': 'worker_1',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_86c76b15-3410-42e6-a908-072d85b8efc5'},
#    'evaluate': {'statistics': {'accuracy': [0.761501210653753,
#       0.7784503631961259,
#       0.7905569007263923,
#       0.562953995157385,
#       0.9394673123486683],
#      'roc_auc_score': [0.8680548561950179,
#       0.38084784321362497,
#       0.6512728609502803,
#       0.6251180358829085,
#       0.5684277317659632],
#      'pr_auc_score': [0.8540798172768274,
#       0.17401756541976046,
#       0.22085700592162064,
#       0.20793890654155134,
#       0.0768116894877214],
#      'f_score': [0.7055306427503737,
#       0.041884816753926704,
#       0.18009478672985782,
#       0.32015065913371,
#       0.0],
#      'TPRs': [0.6361185983827493,
#       0.023121387283236993,
#       0.1532258064516129,
#       0.7083333333333334,
#       0.0],
#      'TNRs': [0.8637362637362638,
#       0.9785604900459418,
#       0.9031339031339032,
#       0.5382436260623229,
#       0.9847715736040609],
#      'PPVs': [0.7919463087248322,
#       0.2222222222222222,
#       0.21839080459770116,
#       0.20681265206812652,
#       0.0],
#      'NPVs': [0.7443181818181818,
#       0.7908415841584159,
#       0.857916102841678,
#       0.9156626506024096,
#       0.9533169533169533],
#      'FPRs': [0.13626373626373625,
#       0.021439509954058193,
#       0.09686609686609686,
#       0.46175637393767704,
#       0.015228426395939087],
#      'FNRs': [0.3638814016172507,
#       0.976878612716763,
#       0.8467741935483871,
#       0.2916666666666667,
#       1.0],
#      'FDRs': [0.2080536912751678,
#       0.7777777777777778,
#       0.7816091954022989,
#       0.7931873479318735,
#       1.0],
#      'TPs': [236, 4, 19, 85, 0],
#      'TNs': [393, 639, 634, 380, 776],
#      'FPs': [62, 14, 68, 326, 12],
#      'FNs': [135, 169, 105, 35, 38]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/optim_run_86c76b15-3410-42e6-a908-072d85b8efc5/evaluate/inference_statistics_evaluate.json'}},
#   {'doc_id': '2',
#    'kind': 'Optimization',
#    'key': {'participant_id': 'worker_2',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_86c76b15-3410-42e6-a908-072d85b8efc5'},
#    'evaluate': {'statistics': {'accuracy': [0.7248603351955307,
#       0.7877094972067039,
#       0.8128491620111732,
#       0.5558659217877095,
#       0.9483240223463687],
#      'roc_auc_score': [0.8094679186228482,
#       0.3934579104049353,
#       0.4695673496076722,
#       0.6169491525423729,
#       0.48231592196349904],
#      'pr_auc_score': [0.7213576990594714,
#       0.16174431386439442,
#       0.176763412665349,
#       0.2316575485761792,
#       0.053997674040318924],
#      'f_score': [0.6609294320137693,
#       0.012987012987012986,
#       0.0821917808219178,
#       0.3813229571984436,
#       0.0],
#      'TPRs': [0.676056338028169,
#       0.006802721088435374,
#       0.04838709677419355,
#       0.7777777777777778,
#       0.0],
#      'TNRs': [0.7569444444444444,
#       0.9894551845342706,
#       0.972972972972973,
#       0.5084745762711864,
#       0.9970631424375918],
#      'PPVs': [0.6464646464646465,
#       0.14285714285714285,
#       0.2727272727272727,
#       0.25257731958762886,
#       0.0],
#      'NPVs': [0.7804295942720764,
#       0.7940761636107193,
#       0.829971181556196,
#       0.9146341463414634,
#       0.9509803921568627],
#      'FPRs': [0.24305555555555555,
#       0.01054481546572935,
#       0.02702702702702703,
#       0.4915254237288136,
#       0.002936857562408223],
#      'FNRs': [0.323943661971831,
#       0.9931972789115646,
#       0.9516129032258065,
#       0.2222222222222222,
#       1.0],
#      'FDRs': [0.35353535353535354,
#       0.8571428571428571,
#       0.7272727272727273,
#       0.7474226804123711,
#       1.0],
#      'TPs': [192, 1, 6, 98, 0],
#      'TNs': [327, 563, 576, 300, 679],
#      'FPs': [105, 6, 16, 290, 2],
#      'FNs': [92, 146, 118, 28, 35]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/optim_run_86c76b15-3410-42e6-a908-072d85b8efc5/evaluate/inference_statistics_evaluate.json'}},
#   {'doc_id': '3',
#    'kind': 'Optimization',
#    'key': {'participant_id': 'worker_1',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_8db47139-d70e-4664-8590-45b294946e32'},
#    'evaluate': {'statistics': {'accuracy': [0.6743341404358354,
#       0.7699757869249395,
#       0.8389830508474576,
#       0.6004842615012107,
#       0.9322033898305084],
#      'roc_auc_score': [0.7563756997719262,
#       0.47906062725172394,
#       0.6953979413656833,
#       0.5550637393767706,
#       0.39911167512690354],
#      'pr_auc_score': [0.707179859675928,
#       0.2020375447939523,
#       0.2653440215260413,
#       0.18998339016326496,
#       0.035794144215316175],
#      'f_score': [0.6616352201257861,
#       0.020618556701030927,
#       0.16352201257861637,
#       0.2633928571428571,
#       0.0],
#      'TPRs': [0.7088948787061995,
#       0.011560693641618497,
#       0.10483870967741936,
#       0.49166666666666664,
#       0.0],
#      'TNRs': [0.6461538461538462,
#       0.9709035222052067,
#       0.9686609686609686,
#       0.6189801699716714,
#       0.9771573604060914],
#      'PPVs': [0.6202830188679245,
#       0.09523809523809523,
#       0.37142857142857144,
#       0.1798780487804878,
#       0.0],
#      'NPVs': [0.7313432835820896,
#       0.7875776397515528,
#       0.8596713021491783,
#       0.8775100401606426,
#       0.9529702970297029],
#      'FPRs': [0.35384615384615387,
#       0.02909647779479326,
#       0.03133903133903134,
#       0.3810198300283286,
#       0.02284263959390863],
#      'FNRs': [0.29110512129380056,
#       0.9884393063583815,
#       0.8951612903225806,
#       0.5083333333333333,
#       1.0],
#      'FDRs': [0.37971698113207547,
#       0.9047619047619048,
#       0.6285714285714286,
#       0.8201219512195121,
#       1.0],
#      'TPs': [263, 2, 13, 59, 0],
#      'TNs': [294, 634, 680, 437, 770],
#      'FPs': [161, 19, 22, 269, 18],
#      'FNs': [108, 171, 111, 61, 38]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/optim_run_8db47139-d70e-4664-8590-45b294946e32/evaluate/inference_statistics_evaluate.json'}},
#   {'doc_id': '4',
#    'kind': 'Optimization',
#    'key': {'participant_id': 'worker_2',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'optim_run_8db47139-d70e-4664-8590-45b294946e32'},
#    'evaluate': {'statistics': {'accuracy': [0.6270949720670391,
#       0.7472067039106145,
#       0.8212290502793296,
#       0.6229050279329609,
#       0.9413407821229051],
#      'roc_auc_score': [0.7359480959833072,
#       0.5189914278540941,
#       0.5289750435919791,
#       0.49587032553134247,
#       0.4224040276903712],
#      'pr_auc_score': [0.6649287976495685,
#       0.20188911834520118,
#       0.20171895746537355,
#       0.1764268323828888,
#       0.039721829369679156],
#      'f_score': [0.6102189781021897,
#       0.09045226130653267,
#       0.0588235294117647,
#       0.2663043478260869,
#       0.04545454545454545],
#      'TPRs': [0.7359154929577465,
#       0.061224489795918366,
#       0.03225806451612903,
#       0.3888888888888889,
#       0.02857142857142857],
#      'TNRs': [0.5555555555555556,
#       0.9244288224956063,
#       0.9864864864864865,
#       0.6728813559322034,
#       0.9882525697503671],
#      'PPVs': [0.5211970074812967,
#       0.17307692307692307,
#       0.3333333333333333,
#       0.2024793388429752,
#       0.1111111111111111],
#      'NPVs': [0.7619047619047619,
#       0.7921686746987951,
#       0.8295454545454546,
#       0.8375527426160337,
#       0.9519094766619519],
#      'FPRs': [0.4444444444444444,
#       0.07557117750439367,
#       0.013513513513513514,
#       0.3271186440677966,
#       0.011747430249632892],
#      'FNRs': [0.2640845070422535,
#       0.9387755102040817,
#       0.967741935483871,
#       0.6111111111111112,
#       0.9714285714285714],
#      'FDRs': [0.47880299251870323,
#       0.8269230769230769,
#       0.6666666666666666,
#       0.7975206611570248,
#       0.8888888888888888],
#      'TPs': [209, 9, 4, 49, 1],
#      'TNs': [240, 526, 584, 397, 673],
#      'FPs': [192, 43, 8, 193, 8],
#      'FNs': [75, 138, 120, 77, 34]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/optim_run_8db47139-d70e-4664-8590-45b294946e32/evaluate/inference_statistics_evaluate.json'}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'optimizations.get',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment'}}

# %% [markdown]
# ## Phase 3: EVALUATE
# Validation & Predictions

# %% [markdown]
# #### 3A. Perform validation(s) of combination(s)

# %%
# Orchestrator performs post-mortem validation
driver.validations.create(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
    log_msg=False,
    verbose=False
)
# Out:
# {'data': [],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'validations.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run'}}

# %%
# Run this cell again after validation has completed to retrieve your validation statistics
# NOTE: You do not need to wait for validation/prediction requests to complete to proceed
driver.validations.read(
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
)
# Out:
# {'data': [{'doc_id': '5',
#    'kind': 'Validation',
#    'key': {'participant_id': 'worker_1',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'heart_disease_syncluster_run'},
#    'evaluate': {'statistics': {'accuracy': [0.36319612590799033,
#       0.7675544794188862,
#       0.8498789346246973,
#       0.851089588377724,
#       0.35714285714285715],
#      'roc_auc_score': [0.3012173810017476,
#       0.5607201975763262,
#       0.47707012223141254,
#       0.32815155807365437,
#       0.4190822869356131],
#      'pr_auc_score': [0.33251664383000057,
#       0.23007077867432313,
#       0.16498278922095844,
#       0.10133199545663223,
#       0.037445457241725114],
#      'f_score': [0.178125,
#       0.030303030303030304,
#       0.0,
#       0.0,
#       0.06349206349206347],
#      'TPRs': [0.15363881401617252,
#       0.017341040462427744,
#       0.0,
#       0.0,
#       0.47368421052631576],
#      'TNRs': [0.5340659340659341,
#       0.9663093415007658,
#       1.0,
#       0.9957507082152974,
#       0.35152284263959394],
#      'PPVs': [0.21189591078066913, 0.12, 0.0, 0.0, 0.034026465028355386],
#      'NPVs': [0.4362657091561939,
#       0.787765293383271,
#       0.8498789346246973,
#       0.8541919805589308,
#       0.9326599326599326],
#      'FPRs': [0.46593406593406594,
#       0.033690658499234305,
#       0.0,
#       0.00424929178470255,
#       0.6484771573604061],
#      'FNRs': [0.8463611859838275,
#       0.9826589595375722,
#       1.0,
#       1.0,
#       0.5263157894736842],
#      'FDRs': [0.7881040892193308, 0.88, 0.0, 1.0, 0.9659735349716446],
#      'TPs': [57, 3, 0, 0, 18],
#      'TNs': [243, 631, 702, 703, 277],
#      'FPs': [212, 22, 0, 3, 511],
#      'FNs': [314, 170, 124, 120, 20]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/evaluate/inference_statistics_evaluate.json'}},
#   {'doc_id': '6',
#    'kind': 'Validation',
#    'key': {'participant_id': 'worker_2',
#     'collab_id': 'heart_disease_syncluster_collaboration',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'heart_disease_syncluster_run'},
#    'evaluate': {'statistics': {'accuracy': [0.4441340782122905,
#       0.7248603351955307,
#       0.8268156424581006,
#       0.8184357541899442,
#       0.33100558659217877],
#      'roc_auc_score': [0.454054186228482,
#       0.5214423203376254,
#       0.5038687881429816,
#       0.4130616088243207,
#       0.29154604573106774],
#      'pr_auc_score': [0.34063833842628877,
#       0.20076176883287045,
#       0.19457624751698874,
#       0.14523231149709526,
#       0.031333890762005066],
#      'f_score': [0.14224137931034483,
#       0.07511737089201877,
#       0.0,
#       0.029850746268656716,
#       0.03621730382293762],
#      'TPRs': [0.11619718309859155,
#       0.05442176870748299,
#       0.0,
#       0.015873015873015872,
#       0.2571428571428571],
#      'TNRs': [0.6597222222222222,
#       0.8980667838312829,
#       1.0,
#       0.9898305084745763,
#       0.33480176211453744],
#      'PPVs': [0.18333333333333332,
#       0.12121212121212122,
#       0.0,
#       0.25,
#       0.01948051948051948],
#      'NPVs': [0.5317164179104478,
#       0.7861538461538462,
#       0.8268156424581006,
#       0.8248587570621468,
#       0.8976377952755905],
#      'FPRs': [0.3402777777777778,
#       0.10193321616871705,
#       0.0,
#       0.010169491525423728,
#       0.6651982378854625],
#      'FNRs': [0.8838028169014085,
#       0.9455782312925171,
#       1.0,
#       0.9841269841269841,
#       0.7428571428571429],
#      'FDRs': [0.8166666666666667,
#       0.8787878787878788,
#       0.0,
#       0.75,
#       0.9805194805194806],
#      'TPs': [33, 8, 0, 2, 9],
#      'TNs': [285, 511, 592, 584, 228],
#      'FPs': [147, 58, 0, 6, 453],
#      'FNs': [251, 139, 124, 124, 26]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/evaluate/inference_statistics_evaluate.json'}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'validations.get',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run'}}

# %% [markdown]
# #### 3B. Perform prediction(s) of combination(s)

# %%
# Worker 1 requests for inferences
driver.predictions.create(
    tags={"heart_disease_syncluster_project": [["heart_disease", "dataset", "data1", "non_iid_1"]]},
    participant_id="worker_1",
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
    log_msg=False,
    verbose=False
)
# Out:
# {'data': [],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'predictions.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run',
#   'participant_id': 'worker_1'}}

# %%
# Run this cell again after prediction has completed to retrieve your predictions for worker 1
# NOTE: You do not need to wait for validation/prediction requests to complete to proceed
driver.predictions.read(
    participant_id="worker_1",
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run"
)
# Out:
# {'data': [{'doc_id': '1',
#    'kind': 'Prediction',
#    'key': {'participant_id': 'worker_1',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'heart_disease_syncluster_run'},
#    'predict': {'statistics': {'accuracy': [0.36319612590799033,
#       0.7675544794188862,
#       0.8498789346246973,
#       0.851089588377724,
#       0.35714285714285715],
#      'roc_auc_score': [0.3012173810017476,
#       0.5607201975763262,
#       0.47707012223141254,
#       0.32815155807365437,
#       0.4190822869356131],
#      'pr_auc_score': [0.33251664383000057,
#       0.23007077867432313,
#       0.16498278922095844,
#       0.10133199545663223,
#       0.037445457241725114],
#      'f_score': [0.178125,
#       0.030303030303030304,
#       0.0,
#       0.0,
#       0.06349206349206347],
#      'TPRs': [0.15363881401617252,
#       0.017341040462427744,
#       0.0,
#       0.0,
#       0.47368421052631576],
#      'TNRs': [0.5340659340659341,
#       0.9663093415007658,
#       1.0,
#       0.9957507082152974,
#       0.35152284263959394],
#      'PPVs': [0.21189591078066913, 0.12, 0.0, 0.0, 0.034026465028355386],
#      'NPVs': [0.4362657091561939,
#       0.787765293383271,
#       0.8498789346246973,
#       0.8541919805589308,
#       0.9326599326599326],
#      'FPRs': [0.46593406593406594,
#       0.033690658499234305,
#       0.0,
#       0.00424929178470255,
#       0.6484771573604061],
#      'FNRs': [0.8463611859838275,
#       0.9826589595375722,
#       1.0,
#       1.0,
#       0.5263157894736842],
#      'FDRs': [0.7881040892193308, 0.88, 0.0, 1.0, 0.9659735349716446],
#      'TPs': [57, 3, 0, 0, 18],
#      'TNs': [243, 631, 702, 703, 277],
#      'FPs': [212, 22, 0, 3, 511],
#      'FNs': [314, 170, 124, 120, 20]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/predict/inference_statistics_predict.json'}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'predictions.get',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run',
#   'participant_id': 'worker_1'}}

# %%
# Worker 2 requests for inferences
driver.predictions.create(
    tags={"heart_disease_syncluster_project": [["heart_disease", "dataset", "data2", "non_iid_2"]]},
    participant_id="worker_2",
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run",
    log_msg=False,
    verbose=False
)
# Out:
# {'data': [],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'predictions.post',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run',
#   'participant_id': 'worker_2'}}

# %%
# Run this cell again after prediction has completed to retrieve your predictions for worker 2
# NOTE: You do not need to wait for validation/prediction requests to complete to proceed
driver.predictions.read(
    participant_id="worker_2",
    collab_id="heart_disease_syncluster_collaboration",
    project_id="heart_disease_syncluster_project",
    expt_id="heart_disease_syncluster_experiment",
    run_id="heart_disease_syncluster_run"
)
# Out:
# {'data': [{'doc_id': '2',
#    'kind': 'Prediction',
#    'key': {'participant_id': 'worker_2',
#     'project_id': 'heart_disease_syncluster_project',
#     'expt_id': 'heart_disease_syncluster_experiment',
#     'run_id': 'heart_disease_syncluster_run'},
#    'predict': {'statistics': {'accuracy': [0.4441340782122905,
#       0.7248603351955307,
#       0.8268156424581006,
#       0.8184357541899442,
#       0.33100558659217877],
#      'roc_auc_score': [0.454054186228482,
#       0.5214423203376254,
#       0.5038687881429816,
#       0.4130616088243207,
#       0.29154604573106774],
#      'pr_auc_score': [0.34063833842628877,
#       0.20076176883287045,
#       0.19457624751698874,
#       0.14523231149709526,
#       0.031333890762005066],
#      'f_score': [0.14224137931034483,
#       0.07511737089201877,
#       0.0,
#       0.029850746268656716,
#       0.03621730382293762],
#      'TPRs': [0.11619718309859155,
#       0.05442176870748299,
#       0.0,
#       0.015873015873015872,
#       0.2571428571428571],
#      'TNRs': [0.6597222222222222,
#       0.8980667838312829,
#       1.0,
#       0.9898305084745763,
#       0.33480176211453744],
#      'PPVs': [0.18333333333333332,
#       0.12121212121212122,
#       0.0,
#       0.25,
#       0.01948051948051948],
#      'NPVs': [0.5317164179104478,
#       0.7861538461538462,
#       0.8268156424581006,
#       0.8248587570621468,
#       0.8976377952755905],
#      'FPRs': [0.3402777777777778,
#       0.10193321616871705,
#       0.0,
#       0.010169491525423728,
#       0.6651982378854625],
#      'FNRs': [0.8838028169014085,
#       0.9455782312925171,
#       1.0,
#       0.9841269841269841,
#       0.7428571428571429],
#      'FDRs': [0.8166666666666667,
#       0.8787878787878788,
#       0.0,
#       0.75,
#       0.9805194805194806],
#      'TPs': [33, 8, 0, 2, 9],
#      'TNs': [285, 511, 592, 584, 228],
#      'FPs': [147, 58, 0, 6, 453],
#      'FNs': [251, 139, 124, 124, 26]},
#     'res_path': '/worker/outputs/heart_disease_syncluster_collaboration/heart_disease_syncluster_project/heart_disease_syncluster_experiment/heart_disease_syncluster_run/predict/inference_statistics_predict.json'}}],
#  'apiVersion': '0.1.0',
#  'success': 1,
#  'status': 200,
#  'method': 'predictions.get',
#  'params': {'collab_id': 'heart_disease_syncluster_collaboration',
#   'project_id': 'heart_disease_syncluster_project',
#   'expt_id': 'heart_disease_syncluster_experiment',
#   'run_id': 'heart_disease_syncluster_run',
#   'participant_id': 'worker_2'}}
